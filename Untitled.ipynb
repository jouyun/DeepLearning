# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from scipy.optimize import curve_fit

# %%
XX=np.linspace(0.1,100, num=10000)
YY=np.exp(-XX/3.1)+np.exp(-XX/6.9)
YY=YY/np.sum(YY)
ZZ=np.exp(-XX/4.1)+np.exp(-XX/6.9)
ZZ=ZZ/np.sum(ZZ)

plt.plot(XX,YY)
plt.xlim([0,16])
# Out:
# (0, 16)
